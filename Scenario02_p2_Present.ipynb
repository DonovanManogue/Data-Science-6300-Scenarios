# %% [markdown]
# <h1 style="color:blue;">Scenario 2 - Part 2</h1>
#
# NOTE: here is guide to use markdown - https://www.markdownguide.org/basic-syntax/
#
#
# Outline of notebook:
# - **C1.S2.Py08 - Understanding .info()**
#     - .info()
# - **C1.S2.Py09 - Understanding data types**
# - **C1.S2.Py10 - Converting objects to dates**
# - **C1.S2.Py11 - How to use groupby for categorical data**
# - **C1.S2.Py12 - How to pivot data**
# - **C1.S2.Py13 - How to melt data**
# - **C1.S2.Py14 - Changing and correcting data**
# - **C1.S2.Py15 - Describing data and looking for outliers**
#     - .describe() and other calculations
# - **C1.S2.Py16 - How to slice Data**
#     - [  ], .iloc, .loc
# - **C1.S2.Py17 - How to filter Data**

# %%
#Code Block 1

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



#style options 

# %matplotlib inline  
#if you want graphs to automatically without plt.show

pd.set_option('display.max_columns',500) #allows for up to 500 columns to be displayed when viewing a dataframe

plt.style.use('seaborn') #a style that can be used for plots - see style reference above
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File /opt/anaconda3/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[176], line 17
#      13 #if you want graphs to automatically without plt.show
#      15 pd.set_option('display.max_columns',500) #allows for up to 500 columns to be displayed when viewing a dataframe
# ---> 17 plt.style.use('seaborn')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/style/core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
#Code Block 2
df = pd.read_csv('data/Scenario2_2.csv', index_col = 0, header=0) 
    #DOES NOT set the first column to the index
    # and the top row as the headers

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py08 - View data info and its properties</h2>
#
# - .info() Allows you to see each column and its corresponding non-null values and data type.
#
# *Documentation - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html*

# %%
#Code Block 3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30071 entries, 0 to 30070
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Member ID                      30071 non-null  int64
#  1   Loan ID                        30071 non-null  int64
#  2   Origination Date               30071 non-null  object
#  3   Interest Rate                  30071 non-null  float64
#  4   Amount Funded                  30071 non-null  int64
#  5   Total Debt                     30063 non-null  float64
#  6   Annual Income                  30071 non-null  int64
#  7   Revolving Accounts             29983 non-null  float64
#  8   Total Revolving Credit Line    30059 non-null  float64
#  9   Term                           30071 non-null  int64
#  10  Grade                          30071 non-null  object
#  11  Employee Title                 28396 non-null  object
#  12  Length of Employment           28990 non-null  float64
#  13  Home Ownership                 30071 non-null  object
#  14  Income Verification            18804 non-null  object
#  15  Loan Purpose                   30071 non-null  object
#  16  Zip Code of Residence          30071 non-null  object
#  17  State of Residence             30071 non-null  object
#  18  Delinquencies Past 24 Months   4877 non-null   float64
#  19  Credit Inquires Last 6 Months  30071 non-null  int64
#  20  Open Accounts                  30071 non-null  int64
# dtypes: float64(6), int64(7), object(8)
# memory usage: 5.0+ MB

# %%
# Code Block 4
df.shape
# Out:
# (30071, 21)

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py09 - Understanding data types</h2>
#
#
# **dtypes** - in parenthesis () python data type
# - object (str or mixed)
#     - Text or mixed numeric and non-numeric values
# - int64 (int)
#     - Integer numbers
# - float64 (float)
#     - Floating point numbers or continuous numbers (have a decimal point)
# - bool (bool)
#     - Boolean or True/False values
# - datetime64 (NA)
#     - Date and time values
# - timedelta[ns]	(NA)
#     - Differences between two datetimes
# - category(NA)
#     - Finite list of text values
#
# <img src="images/DataTypes.png" alt="pivot data" style="width: 600px;"/>
#
#
# *Documentation - https://pbpython.com/pandas_dtypes.html*

# %% [markdown]
# ### Data types for Python variables

# %%
# Code Block 5
varTerm = 36
print(varTerm)
type(varTerm)
# Out:
# 36
# int

# %%
# Code Block 6
print(varTerm + 1)
print(varTerm)
# Out:
# 37
# 36

# %%
# Code Block 7
#varTerm + ' months' #Expect and error - you cannot join a integer and string

# %%
# Code Block 8
str(varTerm) + ' months'
# Out:
# '36 months'

# %%
# Code Block 9
varTermString = str(varTerm)
print(type(varTerm))
print(type(varTermString))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### Data types for pandas DataFrames

# %%
# Code Block 10
df['Interest Rate'].dtypes
# Out:
# dtype('float64')

# %%
# Code Block 11
df['Term'].dtypes
# COMMENT: view info with Shift - Tab
# Out:
# dtype('int64')

# %%
# Code Block 12
df['Total Debt'].dtypes
# Out:
# dtype('float64')

# %%
# Code Block 13
df['TermNum'] = df['Term'] + 1
df.head(2)
# Out:
#    Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 0     149512   848058          8/18/19          19.05           7200
# 1     407046   659709          5/21/18          10.16          16000
#
#    Total Debt  Annual Income  Revolving Accounts  Total Revolving Credit Line  \
# 0    154930.0          58000              3874.0                       4300.0
# 1     29116.0          55000              6840.0                      24800.0
#
#    Term Grade Employee Title  Length of Employment Home Ownership  \
# 0    36     D      Arkwright                   9.0           RENT
# 1    36     B         School                   4.0           RENT
#
#   Income Verification        Loan Purpose Zip Code of Residence  \
# 0     Source Verified  debt_consolidation                 028xx
# 1     Source Verified  debt_consolidation                 926xx
#
#   State of Residence  Delinquencies Past 24 Months  \
# 0                 RI                           NaN
# 1                 CA                           NaN
#
#    Credit Inquires Last 6 Months  Open Accounts  TermNum
# 0                              0              6       37
# 1                              1             12       37

# %%
# Code Block 14
df = df.drop('TermNum', axis = 1) # COMMENT: Drop TermNum since it is not relevant 
#df['TermString'] = df['Term'] + " months"
# COMMENT: You cannot join a integer and string, you must convert the integer to a string first - see Code Block 13

# %%
# Code Block 15
df['TermString'] = df['Term'].astype(str) + " months"

# %%
# Code Block 16
df.head(2)
# Out:
#    Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 0     149512   848058          8/18/19          19.05           7200
# 1     407046   659709          5/21/18          10.16          16000
#
#    Total Debt  Annual Income  Revolving Accounts  Total Revolving Credit Line  \
# 0    154930.0          58000              3874.0                       4300.0
# 1     29116.0          55000              6840.0                      24800.0
#
#    Term Grade Employee Title  Length of Employment Home Ownership  \
# 0    36     D      Arkwright                   9.0           RENT
# 1    36     B         School                   4.0           RENT
#
#   Income Verification        Loan Purpose Zip Code of Residence  \
# 0     Source Verified  debt_consolidation                 028xx
# 1     Source Verified  debt_consolidation                 926xx
#
#   State of Residence  Delinquencies Past 24 Months  \
# 0                 RI                           NaN
# 1                 CA                           NaN
#
#    Credit Inquires Last 6 Months  Open Accounts TermString
# 0                              0              6  36 months
# 1                              1             12  36 months

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30071 entries, 0 to 30070
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Member ID                      30071 non-null  int64
#  1   Loan ID                        30071 non-null  int64
#  2   Origination Date               30071 non-null  object
#  3   Interest Rate                  30071 non-null  float64
#  4   Amount Funded                  30071 non-null  int64
#  5   Total Debt                     30063 non-null  float64
#  6   Annual Income                  30071 non-null  int64
#  7   Revolving Accounts             29983 non-null  float64
#  8   Total Revolving Credit Line    30059 non-null  float64
#  9   Term                           30071 non-null  int64
#  10  Grade                          30071 non-null  object
#  11  Employee Title                 28396 non-null  object
#  12  Length of Employment           28990 non-null  float64
#  13  Home Ownership                 30071 non-null  object
#  14  Income Verification            18804 non-null  object
#  15  Loan Purpose                   30071 non-null  object
#  16  Zip Code of Residence          30071 non-null  object
#  17  State of Residence             30071 non-null  object
#  18  Delinquencies Past 24 Months   4877 non-null   float64
#  19  Credit Inquires Last 6 Months  30071 non-null  int64
#  20  Open Accounts                  30071 non-null  int64
#  21  TermString                     30071 non-null  object
# dtypes: float64(6), int64(7), object(9)
# memory usage: 5.3+ MB

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py10 - Converting dates from objects</h2>
#
# This section changes the columns from an object to a date.
# - csv files import a date as an object
# - xlsx files import a data as a date (no need to convert)
#
# **For every date, you can also create a variable for:**
# - dayofweek
# - month
# - year
# - day
# - dayname
# - etc.

# %%
#Code Block 17
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30071 entries, 0 to 30070
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Member ID                      30071 non-null  int64
#  1   Loan ID                        30071 non-null  int64
#  2   Origination Date               30071 non-null  object
#  3   Interest Rate                  30071 non-null  float64
#  4   Amount Funded                  30071 non-null  int64
#  5   Total Debt                     30063 non-null  float64
#  6   Annual Income                  30071 non-null  int64
#  7   Revolving Accounts             29983 non-null  float64
#  8   Total Revolving Credit Line    30059 non-null  float64
#  9   Term                           30071 non-null  int64
#  10  Grade                          30071 non-null  object
#  11  Employee Title                 28396 non-null  object
#  12  Length of Employment           28990 non-null  float64
#  13  Home Ownership                 30071 non-null  object
#  14  Income Verification            18804 non-null  object
#  15  Loan Purpose                   30071 non-null  object
#  16  Zip Code of Residence          30071 non-null  object
#  17  State of Residence             30071 non-null  object
#  18  Delinquencies Past 24 Months   4877 non-null   float64
#  19  Credit Inquires Last 6 Months  30071 non-null  int64
#  20  Open Accounts                  30071 non-null  int64
#  21  TermString                     30071 non-null  object
# dtypes: float64(6), int64(7), object(9)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Import datetime to be able to convert date to elements of a date (month, year, etc.)
# https://docs.python.org/3/library/datetime.html

# %%
#Code Block 18
import datetime as dt

# %%
#Code Block 19
df['Origination Date'] = pd.to_datetime(df['Origination Date'])
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_57381/3260219459.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Origination Date'] = pd.to_datetime(df['Origination Date'])

# %%
#Code Block 20
df['Day'] = df['Origination Date'].dt.dayofweek
# COMMENT: 0 = Monday, 1 = Tuesday, etc.

# %%
#Code Block 21
df['Month'] = df['Origination Date'].dt.month

# %%
#Code Block 22
df['Year'] = df['Origination Date'].dt.year

# %%
#Code Block 23
df.sample(3)
# Out:
#        Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 25556    3769104   758262       2018-12-30          12.12          16000
# 17775    2697843   800391       2019-04-02           8.90           7000
# 11927    1947077   605597       2018-01-07          18.49          16000
#
#        Total Debt  Annual Income  Revolving Accounts  \
# 25556     21083.0          55000              8181.0
# 17775    112915.0          56400             27106.0
# 11927     78345.0          40000             26260.0
#
#        Total Revolving Credit Line  Term Grade            Employee Title  \
# 25556                      17700.0    36     B              cerda market
# 17775                      48700.0    60     A                       NaN
# 11927                      72400.0    60     D  jeffrey automotive group
#
#        Length of Employment Home Ownership Income Verification  \
# 25556                   4.0           RENT                 NaN
# 17775                   NaN       MORTGAGE            Verified
# 11927                  10.0       MORTGAGE            Verified
#
#              Loan Purpose Zip Code of Residence State of Residence  \
# 25556  debt_consolidation                 064xx                 CT
# 17775                 car                 480xx                 MI
# 11927  debt_consolidation                 480xx                 MI
#
#        Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# 25556                           NaN                              2
# 17775                           NaN                              0
# 11927                           1.0                              3
#
#        Open Accounts TermString  Day  Month  Year
# 25556             12  36 months    6     12  2018
# 17775              8  60 months    1      4  2019
# 11927             12  60 months    6      1  2018

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py11 - How to use groupby for categorical data</h2>

# %% [markdown]
# ### Groupby
# https://pandas.pydata.org/pandas-docs/version/0.22/api.html#groupby
#
# #### Groupby using COUNT and viewing all columns

# %%
#Code Block 24
df.groupby('Loan Purpose').count()
# Out:
#                     Member ID  Loan ID  Origination Date  Interest Rate  \
# Loan Purpose
# car                       351      351               351            351
# credit_card              6764     6764              6764           6764
# debt_consolidation      18141    18141             18141          18141
# home_improvement         1440     1440              1440           1440
# house                     160      160               160            160
# major_purchase            620      620               620            620
# medical                   296      296               296            296
# moving                    160      160               160            160
# other                    1260     1260              1260           1260
# renewable_energy           33       33                33             33
# small_business            432      432               432            432
# vacation                  144      144               144            144
# wedding                   270      270               270            270
#
#                     Amount Funded  Total Debt  Annual Income  \
# Loan Purpose
# car                           351         349            351
# credit_card                  6764        6764           6764
# debt_consolidation          18141       18139          18141
# home_improvement             1440        1439           1440
# house                         160         160            160
# major_purchase                620         619            620
# medical                       296         296            296
# moving                        160         160            160
# other                        1260        1260           1260
# renewable_energy               33          33             33
# small_business                432         431            432
# vacation                      144         143            144
# wedding                       270         270            270
#
#                     Revolving Accounts  Total Revolving Credit Line   Term  \
# Loan Purpose
# car                                343                          351    351
# credit_card                       6760                         6764   6764
# debt_consolidation               18115                        18137  18141
# home_improvement                  1423                         1439   1440
# house                              155                          160    160
# major_purchase                     614                          619    620
# medical                            295                          296    296
# moving                             160                          160    160
# other                             1252                         1258   1260
# renewable_energy                    33                           33     33
# small_business                     427                          430    432
# vacation                           140                          142    144
# wedding                            266                          270    270
#
#                     Grade  Employee Title  Length of Employment  \
# Loan Purpose
# car                   351             333                   339
# credit_card          6764            6362                  6485
# debt_consolidation  18141           17295                 17576
# home_improvement     1440            1324                  1365
# house                 160             145                   151
# major_purchase        620             581                   598
# medical               296             273                   280
# moving                160             149                   151
# other                1260            1164                  1188
# renewable_energy       33              29                    31
# small_business        432             344                   427
# vacation              144             133                   133
# wedding               270             264                   266
#
#                     Home Ownership  Income Verification  \
# Loan Purpose
# car                            351                  167
# credit_card                   6764                 3986
# debt_consolidation           18141                11711
# home_improvement              1440                  893
# house                          160                  102
# major_purchase                 620                  303
# medical                        296                  160
# moving                         160                   83
# other                         1260                  743
# renewable_energy                33                   20
# small_business                 432                  424
# vacation                       144                   63
# wedding                        270                  149
#
#                     Zip Code of Residence  State of Residence  \
# Loan Purpose
# car                                   351                 351
# credit_card                          6764                6764
# debt_consolidation                  18141               18141
# home_improvement                     1440                1440
# house                                 160                 160
# major_purchase                        620                 620
# medical                               296                 296
# moving                                160                 160
# other                                1260                1260
# renewable_energy                       33                  33
# small_business                        432                 432
# vacation                              144                 144
# wedding                               270                 270
#
#                     Delinquencies Past 24 Months  \
# Loan Purpose
# car                                           42
# credit_card                                 1048
# debt_consolidation                          2949
# home_improvement                             285
# house                                         23
# major_purchase                                94
# medical                                       60
# moving                                        19
# other                                        230
# renewable_energy                               8
# small_business                                62
# vacation                                      21
# wedding                                       36
#
#                     Credit Inquires Last 6 Months  Open Accounts  TermString  \
# Loan Purpose
# car                                           351            351         351
# credit_card                                  6764           6764        6764
# debt_consolidation                          18141          18141       18141
# home_improvement                             1440           1440        1440
# house                                         160            160         160
# major_purchase                                620            620         620
# medical                                       296            296         296
# moving                                        160            160         160
# other                                        1260           1260        1260
# renewable_energy                               33             33          33
# small_business                                432            432         432
# vacation                                      144            144         144
# wedding                                       270            270         270
#
#                       Day  Month   Year
# Loan Purpose
# car                   351    351    351
# credit_card          6764   6764   6764
# debt_consolidation  18141  18141  18141
# home_improvement     1440   1440   1440
# house                 160    160    160
# major_purchase        620    620    620
# medical               296    296    296
# moving                160    160    160
# other                1260   1260   1260
# renewable_energy       33     33     33
# small_business        432    432    432
# vacation              144    144    144
# wedding               270    270    270

# %% [markdown]
# #### Groupby using MEAN and viewing one column

# %%
#Code Block 25
df.groupby('Loan Purpose')['Amount Funded'].mean()
# Out:
# Loan Purpose
# car                    7687.891738
# credit_card           13979.017593
# debt_consolidation    15043.152252
# home_improvement      13325.069444
# house                 15823.593750
# major_purchase         8695.403226
# medical                8169.087838
# moving                 6754.375000
# other                  9495.654762
# renewable_energy      10249.242424
# small_business        15773.726852
# vacation               5922.048611
# wedding               10949.259259
# Name: Amount Funded, dtype: float64

# %% [markdown]
# #### Groupby using MEDIAN and viewing one column as a DataFrame

# %%
#Code Block 26
df_loanpurpose = df.groupby('Loan Purpose')['Amount Funded'].median()
df_loanpurpose = pd.DataFrame(df_loanpurpose)
df_loanpurpose
# Out:
#                     Amount Funded
# Loan Purpose
# car                        6275.0
# credit_card               12000.0
# debt_consolidation        14000.0
# home_improvement          10800.0
# house                     14000.0
# major_purchase             6500.0
# medical                    6412.5
# moving                     5312.5
# other                      7500.0
# renewable_energy           8000.0
# small_business            13862.5
# vacation                   5000.0
# wedding                    9437.5

# %% [markdown]
# #### Groupby using MAX and viewing one column as a DataFrame and resetting index

# %%
#Code Block 27
df_loanpurpose2 = df.groupby('Loan Purpose')['Amount Funded'].min()
df_loanpurpose2 = pd.DataFrame(df_loanpurpose2)
df_loanpurpose2 = df_loanpurpose2.reset_index()
df_loanpurpose2
# Out:
#           Loan Purpose  Amount Funded
# 0                  car           1000
# 1          credit_card           1000
# 2   debt_consolidation           1000
# 3     home_improvement           1000
# 4                house           1400
# 5       major_purchase           1000
# 6              medical           1000
# 7               moving           1000
# 8                other           1000
# 9     renewable_energy           2000
# 10      small_business           1000
# 11            vacation           1000
# 12             wedding           1000

# %% [markdown]
# #### Groupby with TWO columns using MEAN and viewing one column

# %%
#Code Block 28
df.groupby(['Loan Purpose', 'Home Ownership'])['Amount Funded'].mean()
# Out:
# Loan Purpose        Home Ownership
# car                 MORTGAGE           7975.000000
#                     OWN                6811.979167
#                     RENT               7612.500000
# credit_card         MORGTAGE           7500.000000
#                     MORTGAGE          15682.588886
#                     NONE              13426.086957
#                     OTHER             13636.458333
#                     OWN               13249.754420
#                     RENT              12124.737762
# debt_consolidation  MORTGAGE          16663.936936
#                     NONE              20119.444444
#                     OTHER             16185.714286
#                     OWN               13695.715962
#                     RENT              13263.350577
# home_improvement    MORGTAGE          10000.000000
#                     MORTGAGE          13912.195652
#                     NONE              13650.000000
#                     OTHER              8181.250000
#                     OWN               10499.852071
#                     RENT              11778.097345
# house               MORTGAGE          18556.779661
#                     OWN               15063.043478
#                     RENT              13980.448718
# major_purchase      MORTGAGE           8561.693548
#                     OWN                9286.500000
#                     RENT               8741.153846
# medical             MORTGAGE           8780.608974
#                     OWN                8000.000000
#                     RENT               7353.828829
# moving              MORTGAGE          10255.714286
#                     OWN                7817.857143
#                     RENT               5516.216216
# other               MORTGAGE          10409.530387
#                     OTHER              6625.000000
#                     OWN               10045.370370
#                     RENT               8586.554276
# renewable_energy    MORTGAGE          11576.666667
#                     OWN                8580.000000
#                     RENT               9359.615385
# small_business      MORTGAGE          17460.426009
#                     OTHER             34475.000000
#                     OWN               15057.812500
#                     RENT              13660.511364
# vacation            MORTGAGE           6157.547170
#                     OWN                5573.750000
#                     RENT               5844.366197
# wedding             MORTGAGE          12236.778846
#                     OWN               11798.611111
#                     RENT               9941.216216
# Name: Amount Funded, dtype: float64

# %% [markdown]
# #### Groupby with two columns using mean and viewing one column as a DataFrame

# %%
#Code Block 29
df_loanown = df.groupby(['Loan Purpose', 'Home Ownership'])['Amount Funded'].mean()
df_loanown = pd.DataFrame(df_loanown).reset_index()
df_loanown
# Out:
#           Loan Purpose Home Ownership  Amount Funded
# 0                  car       MORTGAGE    7975.000000
# 1                  car            OWN    6811.979167
# 2                  car           RENT    7612.500000
# 3          credit_card       MORGTAGE    7500.000000
# 4          credit_card       MORTGAGE   15682.588886
# 5          credit_card           NONE   13426.086957
# 6          credit_card          OTHER   13636.458333
# 7          credit_card            OWN   13249.754420
# 8          credit_card           RENT   12124.737762
# 9   debt_consolidation       MORTGAGE   16663.936936
# 10  debt_consolidation           NONE   20119.444444
# 11  debt_consolidation          OTHER   16185.714286
# 12  debt_consolidation            OWN   13695.715962
# 13  debt_consolidation           RENT   13263.350577
# 14    home_improvement       MORGTAGE   10000.000000
# 15    home_improvement       MORTGAGE   13912.195652
# 16    home_improvement           NONE   13650.000000
# 17    home_improvement          OTHER    8181.250000
# 18    home_improvement            OWN   10499.852071
# 19    home_improvement           RENT   11778.097345
# 20               house       MORTGAGE   18556.779661
# 21               house            OWN   15063.043478
# 22               house           RENT   13980.448718
# 23      major_purchase       MORTGAGE    8561.693548
# 24      major_purchase            OWN    9286.500000
# 25      major_purchase           RENT    8741.153846
# 26             medical       MORTGAGE    8780.608974
# 27             medical            OWN    8000.000000
# 28             medical           RENT    7353.828829
# 29              moving       MORTGAGE   10255.714286
# 30              moving            OWN    7817.857143
# 31              moving           RENT    5516.216216
# 32               other       MORTGAGE   10409.530387
# 33               other          OTHER    6625.000000
# 34               other            OWN   10045.370370
# 35               other           RENT    8586.554276
# 36    renewable_energy       MORTGAGE   11576.666667
# 37    renewable_energy            OWN    8580.000000
# 38    renewable_energy           RENT    9359.615385
# 39      small_business       MORTGAGE   17460.426009
# 40      small_business          OTHER   34475.000000
# 41      small_business            OWN   15057.812500
# 42      small_business           RENT   13660.511364
# 43            vacation       MORTGAGE    6157.547170
# 44            vacation            OWN    5573.750000
# 45            vacation           RENT    5844.366197
# 46             wedding       MORTGAGE   12236.778846
# 47             wedding            OWN   11798.611111
# 48             wedding           RENT    9941.216216

# %%
#Code Block 30
df.groupby(['Home Ownership'])['Home Ownership'].count()
# Out:
# Home Ownership
# MORGTAGE        2
# MORTGAGE    15482
# NONE           35
# OTHER          37
# OWN          2303
# RENT        12212
# Name: Home Ownership, dtype: int64

# %% [markdown]
# #### NOTE:
# We will address the misspellings of MORGTAGE in another video (**C1.S4.Py05- Changing and correcting data**)

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py12 - How to pivot data</h2>

# %% [markdown]
# - View the sum of all loans per year and month based on reason for leaving
#
# images from: https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
#
# #### Pivot
#
# - Take one column and expand it multiple columns
# - pivot = df.pivot_table(index='index', columns='categorical value', values='numerical value')
# - set index as an identifier
# - set the columns to the column that has the different categories that will be your headers
# - set the values to a specific numerical column
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.pivot.html
#
# <img src="images/reshaping_pivot.png" alt="pivot data" style="width: 600px;"/>
#
# #### Melt
# - set dataset
# - set variables to include that are not melted - id_vars
# - melt variable - value_vars
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.melt.html <br>
#
# <img src="images/reshaping_melt.png" alt="melt data" style="width: 600px;"/>

# %%
#Code Block 31
df.head()
# Out:
#    Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 0     149512   848058       2019-08-18          19.05           7200
# 1     407046   659709       2018-05-21          10.16          16000
# 2     507531   601368       2018-01-01          10.16          35000
# 3     513904   761341       2019-01-03           6.03          21000
# 4     603349   885844       2019-11-17          16.29          15000
#
#    Total Debt  Annual Income  Revolving Accounts  Total Revolving Credit Line  \
# 0    154930.0          58000              3874.0                       4300.0
# 1     29116.0          55000              6840.0                      24800.0
# 2     60019.0         130000             23025.0                      55800.0
# 3     37603.0         120000             18641.0                      85031.0
# 4    227890.0          72000             11702.0                      26300.0
#
#    Term Grade        Employee Title  Length of Employment Home Ownership  \
# 0    36     D             Arkwright                   9.0           RENT
# 1    36     B                School                   4.0           RENT
# 2    36     B                 gSEMI                   8.0           RENT
# 3    36     A  Fidelity Investments                  10.0           RENT
# 4    36     C                   NaN                   NaN       MORTGAGE
#
#   Income Verification        Loan Purpose Zip Code of Residence  \
# 0     Source Verified  debt_consolidation                 028xx
# 1     Source Verified  debt_consolidation                 926xx
# 2            Verified         credit_card                 940xx
# 3                 NaN  debt_consolidation                 021xx
# 4            Verified               house                 341xx
#
#   State of Residence  Delinquencies Past 24 Months  \
# 0                 RI                           NaN
# 1                 CA                           NaN
# 2                 CA                           NaN
# 3                 MA                           NaN
# 4                 FL                           NaN
#
#    Credit Inquires Last 6 Months  Open Accounts TermString  Day  Month  Year
# 0                              0              6  36 months    6      8  2019
# 1                              1             12  36 months    0      5  2018
# 2                              1             11  36 months    0      1  2018
# 3                              0             16  36 months    3      1  2019
# 4                              1             18  36 months    6     11  2019

# %% [markdown]
# #### Pivot data
# - Loan Purpose as the rows
# - Home Ownership as the columns
# - Amount Funded average as the values

# %%
#Code Block 32
df_pivot = df.pivot_table(index='Loan Purpose', columns='Home Ownership', values='Amount Funded')
df_pivot
# Out:
# Home Ownership      MORGTAGE      MORTGAGE          NONE         OTHER  \
# Loan Purpose
# car                      NaN   7975.000000           NaN           NaN
# credit_card           7500.0  15682.588886  13426.086957  13636.458333
# debt_consolidation       NaN  16663.936936  20119.444444  16185.714286
# home_improvement     10000.0  13912.195652  13650.000000   8181.250000
# house                    NaN  18556.779661           NaN           NaN
# major_purchase           NaN   8561.693548           NaN           NaN
# medical                  NaN   8780.608974           NaN           NaN
# moving                   NaN  10255.714286           NaN           NaN
# other                    NaN  10409.530387           NaN   6625.000000
# renewable_energy         NaN  11576.666667           NaN           NaN
# small_business           NaN  17460.426009           NaN  34475.000000
# vacation                 NaN   6157.547170           NaN           NaN
# wedding                  NaN  12236.778846           NaN           NaN
#
# Home Ownership               OWN          RENT
# Loan Purpose
# car                  6811.979167   7612.500000
# credit_card         13249.754420  12124.737762
# debt_consolidation  13695.715962  13263.350577
# home_improvement    10499.852071  11778.097345
# house               15063.043478  13980.448718
# major_purchase       9286.500000   8741.153846
# medical              8000.000000   7353.828829
# moving               7817.857143   5516.216216
# other               10045.370370   8586.554276
# renewable_energy     8580.000000   9359.615385
# small_business      15057.812500  13660.511364
# vacation             5573.750000   5844.366197
# wedding             11798.611111   9941.216216

# %% [markdown]
# #### Pivot data and reset index
# - Loan Purpose as the rows
# - Home Ownership as the columns
# - Amount Funded average as the values

# %%
#Code Block 33
df_pivot = df_pivot.reset_index()
df_pivot.head()
# Out:
# Home Ownership        Loan Purpose  MORGTAGE      MORTGAGE          NONE  \
# 0                              car       NaN   7975.000000           NaN
# 1                      credit_card    7500.0  15682.588886  13426.086957
# 2               debt_consolidation       NaN  16663.936936  20119.444444
# 3                 home_improvement   10000.0  13912.195652  13650.000000
# 4                            house       NaN  18556.779661           NaN
#
# Home Ownership         OTHER           OWN          RENT
# 0                        NaN   6811.979167   7612.500000
# 1               13636.458333  13249.754420  12124.737762
# 2               16185.714286  13695.715962  13263.350577
# 3                8181.250000  10499.852071  11778.097345
# 4                        NaN  15063.043478  13980.448718

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py13 - How to melt data</h2>
#
# #### Melt Data
# - Create a list of column names of the columns that you want to melt/merge into one column.
#     - MORTGAGE, NONE, OTHER, OWN, and RENT
# - Melt the data by:
#     - Specify the dataset - ***df_columns***.
#     - Specify LOAN PURPOSE as the *id_vars*.
#     - Taking 5 columns (***MORTGAGE, NONE, OTHER, OWN,*** and ***RENT***) into one column by specifying column names for *value_vars* by using the ***df_pivot_columns***.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.melt.html <br>
#
# <img src="images/reshaping_melt.png" alt="melt data" style="width: 600px;"/>

# %%
#Code Block 34
df_pivot_columns = df_pivot.columns
df_pivot_columns
# COMMENT: This creates the list of column names for value_vars in the melt function
# Out:
# Index(['Loan Purpose', 'MORGTAGE', 'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT'], dtype='object', name='Home Ownership')

# %%
#Code Block 35
df_pivot_columns = df_pivot_columns.drop('Loan Purpose')
df_pivot_columns
# COMMENT: Drop Loan Purpose, since this is not one of the columns that should be melted into one column.
# Out:
# Index(['MORGTAGE', 'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT'], dtype='object', name='Home Ownership')

# %%
#Code Block 36
df_melt =pd.melt(df_pivot, id_vars=['Loan Purpose'], value_vars=df_pivot_columns)
df_melt.head(15)
# Out:
#           Loan Purpose Home Ownership         value
# 0                  car       MORGTAGE           NaN
# 1          credit_card       MORGTAGE   7500.000000
# 2   debt_consolidation       MORGTAGE           NaN
# 3     home_improvement       MORGTAGE  10000.000000
# 4                house       MORGTAGE           NaN
# 5       major_purchase       MORGTAGE           NaN
# 6              medical       MORGTAGE           NaN
# 7               moving       MORGTAGE           NaN
# 8                other       MORGTAGE           NaN
# 9     renewable_energy       MORGTAGE           NaN
# 10      small_business       MORGTAGE           NaN
# 11            vacation       MORGTAGE           NaN
# 12             wedding       MORGTAGE           NaN
# 13                 car       MORTGAGE   7975.000000
# 14         credit_card       MORTGAGE  15682.588886

# %%
#Code Block 37
df_melt.sort_values(by=['Loan Purpose'], ascending = True).head(15)
# Out:
#           Loan Purpose Home Ownership         value
# 0                  car       MORGTAGE           NaN
# 26                 car           NONE           NaN
# 52                 car            OWN   6811.979167
# 13                 car       MORTGAGE   7975.000000
# 65                 car           RENT   7612.500000
# 39                 car          OTHER           NaN
# 1          credit_card       MORGTAGE   7500.000000
# 53         credit_card            OWN  13249.754420
# 66         credit_card           RENT  12124.737762
# 40         credit_card          OTHER  13636.458333
# 27         credit_card           NONE  13426.086957
# 14         credit_card       MORTGAGE  15682.588886
# 2   debt_consolidation       MORGTAGE           NaN
# 28  debt_consolidation           NONE  20119.444444
# 54  debt_consolidation            OWN  13695.715962

# %%
#Code Block 38
df_melt=df_melt.rename(columns = {'value': 'Amount Funded'})
df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan Purpose    78 non-null     object
#  1   Home Ownership  78 non-null     object
#  2   Amount Funded   49 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ KB

# %%
#Code Block 39
df_melt = df_melt.dropna(subset=['Amount Funded'])
df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 1 to 77
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan Purpose    49 non-null     object
#  1   Home Ownership  49 non-null     object
#  2   Amount Funded   49 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ KB

# %%
#Code Block 40
df_melt.sort_values(by=['Loan Purpose'], ascending = True).head(15)
# Out:
#           Loan Purpose Home Ownership  Amount Funded
# 13                 car       MORTGAGE    7975.000000
# 65                 car           RENT    7612.500000
# 52                 car            OWN    6811.979167
# 1          credit_card       MORGTAGE    7500.000000
# 66         credit_card           RENT   12124.737762
# 40         credit_card          OTHER   13636.458333
# 27         credit_card           NONE   13426.086957
# 53         credit_card            OWN   13249.754420
# 14         credit_card       MORTGAGE   15682.588886
# 54  debt_consolidation            OWN   13695.715962
# 15  debt_consolidation       MORTGAGE   16663.936936
# 67  debt_consolidation           RENT   13263.350577
# 28  debt_consolidation           NONE   20119.444444
# 41  debt_consolidation          OTHER   16185.714286
# 29    home_improvement           NONE   13650.000000

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py14 - Changing and correcting data</h2>
#
# NOTE: This video addresses the misspellings of MORGTAGE in **C1.S4.Py04a - Using groupby for categorical data**

# %%
#Code Block 41
df.groupby(['Home Ownership'])['Home Ownership'].count()
# Out:
# Home Ownership
# MORGTAGE        2
# MORTGAGE    15482
# NONE           35
# OTHER          37
# OWN          2303
# RENT        12212
# Name: Home Ownership, dtype: int64

# %%
#Code Block 42
df[df['Home Ownership'] == 'MORGTAGE' ]
# Out:
#    Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 6     735990   789789       2019-02-17           7.62           7500
# 8     778284   746115       2018-12-13           6.03          10000
#
#    Total Debt  Annual Income  Revolving Accounts  Total Revolving Credit Line  \
# 6    265809.0          92000              6419.0                      43000.0
# 8    152402.0         108000              4653.0                      46100.0
#
#    Term Grade     Employee Title  Length of Employment Home Ownership  \
# 6    36     A            TD Bank                   4.0       MORGTAGE
# 8    36     A  FlightStats, Inc.                   1.0       MORGTAGE
#
#   Income Verification      Loan Purpose Zip Code of Residence  \
# 6                 NaN       credit_card                 030xx
# 8                 NaN  home_improvement                 750xx
#
#   State of Residence  Delinquencies Past 24 Months  \
# 6                 NH                           NaN
# 8                 TX                           NaN
#
#    Credit Inquires Last 6 Months  Open Accounts TermString  Day  Month  Year
# 6                              2              5  36 months    6      2  2019
# 8                              0             10  36 months    3     12  2018

# %%
#Code Block 43
df = df.replace('MORGTAGE', 'MORTGAGE')
df.groupby(['Home Ownership'])['Home Ownership'].count()
# Out:
# Home Ownership
# MORTGAGE    15484
# NONE           35
# OTHER          37
# OWN          2303
# RENT        12212
# Name: Home Ownership, dtype: int64

# %%
#Code Block 44
df_openacc = df.copy()
df_openacc = df_openacc[df_openacc['Open Accounts']>20]
print(df_openacc['Open Accounts'].count())
df_openacc.groupby(['Open Accounts'])['Open Accounts'].count()
# Out:
# 1024
# Open Accounts
# 21    307
# 22    209
# 23    163
# 24    127
# 25     74
# 26     34
# 27     25
# 28     18
# 29     15
# 30      9
# 31     12
# 32      4
# 33      3
# 34      6
# 35      5
# 37      2
# 38      1
# 39      4
# 43      1
# 44      1
# 46      1
# 50      1
# 52      1
# 53      1
# Name: Open Accounts, dtype: int64

# %%
#Code Block 45
df_openacc[df_openacc['Open Accounts']>30] = 30 
df_openacc.groupby(['Open Accounts'])['Open Accounts'].count()
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_57381/2535019171.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df_openacc[df_openacc['Open Accounts']>30] = 30
# Open Accounts
# 21    307
# 22    209
# 23    163
# 24    127
# 25     74
# 26     34
# 27     25
# 28     18
# 29     15
# 30     52
# Name: Open Accounts, dtype: int64

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py15 - Describing data and looking for outliers</h2>

# %% [markdown]
# ### Describing data
# - .describe()
# - other types of calculations can be found at https://pandas.pydata.org/pandas-docs/stable/reference/frame.html and look for the Computations / descriptive statistics heading

# %%
#Code Block 46
df.describe()
# Out:
#           Member ID        Loan ID               Origination Date  \
# count  3.007100e+04   30071.000000                          30071
# mean   2.558148e+06  758572.627814  2019-01-08 12:45:05.117887744
# min    1.495120e+05  600947.000000            2018-01-01 00:00:00
# 25%    1.837828e+06  679267.000000            2018-07-19 00:00:00
# 50%    2.287587e+06  758139.000000            2018-12-30 00:00:00
# 75%    3.408782e+06  838127.000000            2019-07-16 00:00:00
# max    4.076727e+06  917123.000000            2019-12-30 00:00:00
# std    8.106320e+05   91431.818948                            NaN
#
#        Interest Rate  Amount Funded    Total Debt  Annual Income  \
# count   30071.000000   30071.000000  3.006300e+04   3.007100e+04
# mean       13.761040   14089.528117  1.365667e+05   7.378315e+04
# min         6.000000    1000.000000  5.000000e+00   7.200000e+03
# 25%        11.140000    8000.000000  2.660150e+04   4.500000e+04
# 50%        14.090000   12000.000000  7.526200e+04   6.300000e+04
# 75%        16.290000   19750.000000  2.069760e+05   8.800000e+04
# max        24.890000   35000.000000  8.000078e+06   7.141778e+06
# std         4.179612    8045.157332  1.607559e+05   8.012846e+04
#
#        Revolving Accounts  Total Revolving Credit Line          Term  \
# count        2.998300e+04                 3.005900e+04  30071.000000
# mean         1.685330e+04                 2.987683e+04     40.098301
# min          4.000000e+00                 1.000000e+02     36.000000
# 25%          7.438000e+03                 1.410000e+04     36.000000
# 50%          1.287600e+04                 2.320000e+04     36.000000
# 75%          2.152350e+04                 3.724550e+04     36.000000
# max          1.743266e+06                 2.013133e+06     60.000000
# std          2.107094e+04                 3.007873e+04      9.031382
#
#        Length of Employment  Delinquencies Past 24 Months  \
# count          28990.000000                   4877.000000
# mean               6.073577                      1.476727
# min                1.000000                      1.000000
# 25%                3.000000                      1.000000
# 50%                6.000000                      1.000000
# 75%               10.000000                      2.000000
# max               10.000000                     18.000000
# std                3.438755                      1.027374
#
#        Credit Inquires Last 6 Months  Open Accounts           Day  \
# count                   30071.000000   30071.000000  30071.000000
# mean                        0.820525      10.982907      2.864221
# min                         0.000000       0.000000      0.000000
# 25%                         0.000000       8.000000      1.000000
# 50%                         1.000000      10.000000      3.000000
# 75%                         1.000000      14.000000      6.000000
# max                         8.000000      53.000000      6.000000
# std                         1.019112       4.523027      2.299424
#
#               Month          Year
# count  30071.000000  30071.000000
# mean       6.841209   2018.495694
# min        1.000000   2018.000000
# 25%        4.000000   2018.000000
# 50%        7.000000   2018.000000
# 75%       11.000000   2019.000000
# max       12.000000   2019.000000
# std        3.927091      0.499990

# %%
#Code Block 47
df['Amount Funded'].describe()
# Out:
# count    30071.000000
# mean     14089.528117
# std       8045.157332
# min       1000.000000
# 25%       8000.000000
# 50%      12000.000000
# 75%      19750.000000
# max      35000.000000
# Name: Amount Funded, dtype: float64

# %%
#Code Block 48
AmountFundedStats = df['Amount Funded'].describe().reset_index()
AmountFundedStats
# Out:
#    index  Amount Funded
# 0  count   30071.000000
# 1   mean   14089.528117
# 2    std    8045.157332
# 3    min    1000.000000
# 4    25%    8000.000000
# 5    50%   12000.000000
# 6    75%   19750.000000
# 7    max   35000.000000

# %%
#Code Block 49
df['Amount Funded'].mean()
# Out:
# 14089.528116790263

# %%
#Code Block 50
df['Amount Funded'].median()
# Out:
# 12000.0

# %%
#Code Block 51
AmountFundedSTD = df['Amount Funded'].std()
AmountFundedSTD = round(AmountFundedSTD,2)
AmountFundedSTD
# Out:
# 8045.16

# %%
#Code Block 52
print('The Standard Deviation is ' + str(df['Amount Funded'].std()))
# Out:
# The Standard Deviation is 8045.15733158739

# %%
#Code Block 53
print ('---------------------------------')
print('The Mean is:')
print(df['Amount Funded'].mean())
print ('---------------------------------')
print('The Median is:')
print(df['Amount Funded'].median())
print ('---------------------------------')
print('The Standard Deviation is:')
print(df['Amount Funded'].std())
print ('---------------------------------')
print('The Variance is:')
print(round(df['Amount Funded'].var(), 2))
print ('---------------------------------')
print('The Skewness is:')
print(round(df['Amount Funded'].skew(), 4))
print ('---------------------------------')
# Out:
# ---------------------------------
# The Mean is:
# 14089.528116790263
# ---------------------------------
# The Median is:
# 12000.0
# ---------------------------------
# The Standard Deviation is:
# 8045.15733158739
# ---------------------------------
# The Variance is:
# 64724556.49
# ---------------------------------
# The Skewness is:
# 0.7313
# ---------------------------------

# %%
df['Loan Purpose'].value_counts()
# Out:
# Loan Purpose
# debt_consolidation    18141
# credit_card            6764
# home_improvement       1440
# other                  1260
# major_purchase          620
# small_business          432
# car                     351
# medical                 296
# wedding                 270
# house                   160
# moving                  160
# vacation                144
# renewable_energy         33
# Name: count, dtype: int64

# %%
df['Home Ownership'].value_counts(normalize=True)
# Out:
# Home Ownership
# MORTGAGE    0.514915
# RENT        0.406106
# OWN         0.076585
# OTHER       0.001230
# NONE        0.001164
# Name: proportion, dtype: float64

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py16 - Looking for outliers</h2>

# %%
#Code Block 54
df['Loan Purpose'].value_counts()
# Out:
# Loan Purpose
# debt_consolidation    18141
# credit_card            6764
# home_improvement       1440
# other                  1260
# major_purchase          620
# small_business          432
# car                     351
# medical                 296
# wedding                 270
# house                   160
# moving                  160
# vacation                144
# renewable_energy         33
# Name: count, dtype: int64

# %%
#Code Block 55
df['Home Ownership'].value_counts(normalize=True)
# Out:
# Home Ownership
# MORTGAGE    0.514915
# RENT        0.406106
# OWN         0.076585
# OTHER       0.001230
# NONE        0.001164
# Name: proportion, dtype: float64

# %%
#Code Block 56
df[df['Annual Income'] > 1000000 ].sort_values('Annual Income', ascending=False)
# Out:
#        Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 22304    3267055   726952       2018-11-14          13.11          14825
# 29333    3979312   648723       2018-04-16          12.12          30000
# 20416    2839463   742564       2018-12-09          15.31          35000
# 29607    3983192   677675       2018-07-15          15.80          35000
# 82       1407521   609446       2018-01-11          21.00          24000
# 21507    2977671   643050       2018-04-05          13.11          18000
# 16408    2432841   855970       2019-09-16           8.90          20000
# 18028    2726748   814579       2019-04-29          19.72          35000
# 4773     1797692   761520       2019-01-03          12.12          35000
# 21110    2926819   619179       2018-01-23          11.14          30000
# 27676    3876448   737805       2018-12-02           8.90          21250
#
#        Total Debt  Annual Income  Revolving Accounts  \
# 22304     69548.0        7141778             11351.0
# 29333    329254.0        6100000             15219.0
# 20416   8000078.0        5000000            975800.0
# 29607   1528010.0        2000000            694615.0
# 82        49281.0        1500000             18544.0
# 21507     66705.0        1350000             17148.0
# 16408    575475.0        1250000             22427.0
# 18028     75069.0        1250000             11419.0
# 4773    2008009.0        1200000             20228.0
# 21110    375355.0        1200000             81138.0
# 27676    221218.0        1200000             12367.0
#
#        Total Revolving Credit Line  Term Grade              Employee Title  \
# 22304                      16000.0    36     B           Us postal service
# 29333                      16100.0    36     B     BOONE AND SONS JEWELERS
# 20416                     988000.0    36     C     VISIUM asset management
# 29607                     757500.0    60     C          R Markey &Sons Inc
# 82                         24000.0    60     E                        sfpd
# 21507                      34200.0    36     B  Argus Health Stystems, Inc
# 16408                      70700.0    36     A                   PACAF PMO
# 18028                      18600.0    60     D                 BAE Systems
# 4773                       42300.0    36     B          Highbridge Capital
# 21110                     105400.0    36     B             Murray's Cheese
# 27676                      20900.0    36     A                         UPS
#
#        Length of Employment Home Ownership Income Verification  \
# 22304                  10.0       MORTGAGE     Source Verified
# 29333                  10.0       MORTGAGE            Verified
# 20416                  10.0       MORTGAGE            Verified
# 29607                   5.0       MORTGAGE     Source Verified
# 82                      7.0            OWN            Verified
# 21507                   7.0       MORTGAGE     Source Verified
# 16408                   3.0       MORTGAGE     Source Verified
# 18028                  10.0           RENT     Source Verified
# 4773                    5.0       MORTGAGE     Source Verified
# 21110                   6.0            OWN     Source Verified
# 27676                  10.0       MORTGAGE            Verified
#
#              Loan Purpose Zip Code of Residence State of Residence  \
# 22304  debt_consolidation                 317xx                 GA
# 29333  debt_consolidation                 207xx                 MD
# 20416         credit_card                 112xx                 NY
# 29607  debt_consolidation                 110xx                 NY
# 82     debt_consolidation                 946xx                 CA
# 21507  debt_consolidation                 661xx                 KS
# 16408    home_improvement                 967xx                 HI
# 18028  debt_consolidation                 480xx                 MI
# 4773                other                 105xx                 NY
# 21110  debt_consolidation                 108xx                 NY
# 27676         credit_card                 481xx                 MI
#
#        Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# 22304                           NaN                              2
# 29333                           NaN                              0
# 20416                           1.0                              2
# 29607                           NaN                              2
# 82                              NaN                              0
# 21507                           NaN                              5
# 16408                           NaN                              2
# 18028                           1.0                              1
# 4773                            NaN                              2
# 21110                           NaN                              0
# 27676                           NaN                              0
#
#        Open Accounts TermString  Day  Month  Year
# 22304             17  36 months    2     11  2018
# 29333              8  36 months    0      4  2018
# 20416             13  36 months    6     12  2018
# 29607             14  60 months    6      7  2018
# 82                20  60 months    3      1  2018
# 21507             10  36 months    3      4  2018
# 16408             19  36 months    0      9  2019
# 18028             12  60 months    0      4  2019
# 4773               5  36 months    3      1  2019
# 21110             16  36 months    1      1  2018
# 27676             13  36 months    6     12  2018

# %%
#Code Block 48
df[df['Amount Funded'] == 35000 ].sort_values('Annual Income', ascending=False).head(15)
# Out:
#        Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 20416    2839463   742564       2018-12-09          15.31          35000
# 29607    3983192   677675       2018-07-15          15.80          35000
# 18028    2726748   814579       2019-04-29          19.72          35000
# 4773     1797692   761520       2019-01-03          12.12          35000
# 4070     1787504   825611       2019-06-12          20.49          35000
# 21691    3016955   881434       2019-11-07          15.80          35000
# 25822    3777698   853904       2019-09-09          21.00          35000
# 21080    2917830   617029       2018-01-21          16.29          35000
# 29558    3982604   689878       2018-08-26          12.12          35000
# 22384    3376772   701085       2018-09-30          11.14          35000
# 2101     1754958   616050       2018-01-21          12.12          35000
# 22837    3417245   668938       2018-06-20          16.29          35000
# 14197    2126967   716798       2018-10-29          18.75          35000
# 27079    3869263   739452       2018-12-04          15.31          35000
# 17108    2627993   683794       2018-07-30          10.16          35000
#
#        Total Debt  Annual Income  Revolving Accounts  \
# 20416   8000078.0        5000000            975800.0
# 29607   1528010.0        2000000            694615.0
# 18028     75069.0        1250000             11419.0
# 4773    2008009.0        1200000             20228.0
# 4070     862656.0         845000             51228.0
# 21691   4772549.0         800000             54511.0
# 25822    675477.0         729368             92841.0
# 21080   1324144.0         650000            303993.0
# 29558    771617.0         650000             33262.0
# 22384   1175696.0         600000            264260.0
# 2101     342006.0         500000              6390.0
# 22837   2547166.0         500000            552758.0
# 14197    596038.0         500000             32559.0
# 27079    120995.0         500000             12876.0
# 17108     92612.0         500000             48119.0
#
#        Total Revolving Credit Line  Term Grade               Employee Title  \
# 20416                     988000.0    36     C      VISIUM asset management
# 29607                     757500.0    60     C           R Markey &Sons Inc
# 18028                      18600.0    60     D                  BAE Systems
# 4773                       42300.0    36     B           Highbridge Capital
# 4070                      241300.0    60     E                          NaN
# 21691                      62404.0    36     C      Standard Chartered Bank
# 25822                     101900.0    60     E                  DA Davidson
# 21080                     334500.0    60     C                William Blair
# 29558                      42300.0    36     B                     Deloitte
# 22384                     344900.0    36     B  University of South Florida
# 2101                       32300.0    60     B                Goldman Sachs
# 22837                     645800.0    60     C                         Bank
# 14197                      41663.0    36     D                          NaN
# 27079                      20100.0    36     C      Infiniti Home Loans Inc
# 17108                     157900.0    36     B                          NaN
#
#        Length of Employment Home Ownership Income Verification  \
# 20416                  10.0       MORTGAGE            Verified
# 29607                   5.0       MORTGAGE     Source Verified
# 18028                  10.0           RENT     Source Verified
# 4773                    5.0       MORTGAGE     Source Verified
# 4070                   10.0       MORTGAGE            Verified
# 21691                   2.0       MORTGAGE     Source Verified
# 25822                  10.0       MORTGAGE            Verified
# 21080                   5.0       MORTGAGE            Verified
# 29558                  10.0       MORTGAGE     Source Verified
# 22384                   2.0       MORTGAGE     Source Verified
# 2101                    7.0           RENT     Source Verified
# 22837                  10.0       MORTGAGE            Verified
# 14197                  10.0       MORTGAGE     Source Verified
# 27079                   4.0           RENT            Verified
# 17108                  10.0           RENT     Source Verified
#
#              Loan Purpose Zip Code of Residence State of Residence  \
# 20416         credit_card                 112xx                 NY
# 29607  debt_consolidation                 110xx                 NY
# 18028  debt_consolidation                 480xx                 MI
# 4773                other                 105xx                 NY
# 4070     home_improvement                 110xx                 NY
# 21691         credit_card                 100xx                 NY
# 25822    home_improvement                 641xx                 MO
# 21080  debt_consolidation                 068xx                 CT
# 29558  debt_consolidation                 070xx                 NJ
# 22384               house                 336xx                 FL
# 2101              wedding                 100xx                 NY
# 22837  debt_consolidation                 949xx                 CA
# 14197  debt_consolidation                 936xx                 CA
# 27079  debt_consolidation                 926xx                 CA
# 17108         credit_card                 941xx                 CA
#
#        Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# 20416                           1.0                              2
# 29607                           NaN                              2
# 18028                           1.0                              1
# 4773                            NaN                              2
# 4070                            NaN                              2
# 21691                           NaN                              3
# 25822                           1.0                              1
# 21080                           NaN                              1
# 29558                           NaN                              1
# 22384                           NaN                              1
# 2101                            NaN                              0
# 22837                           NaN                              1
# 14197                           NaN                              2
# 27079                           NaN                              4
# 17108                           NaN                              0
#
#        Open Accounts TermString  Day  Month  Year
# 20416             13  36 months    6     12  2018
# 29607             14  60 months    6      7  2018
# 18028             12  60 months    0      4  2019
# 4773               5  36 months    3      1  2019
# 4070              15  60 months    2      6  2019
# 21691             12  36 months    3     11  2019
# 25822             11  60 months    0      9  2019
# 21080             12  60 months    6      1  2018
# 29558             13  36 months    6      8  2018
# 22384             12  36 months    6      9  2018
# 2101              10  60 months    6      1  2018
# 22837             15  60 months    2      6  2018
# 14197             20  36 months    0     10  2018
# 27079              8  36 months    1     12  2018
# 17108             11  36 months    0      7  2018

# %%
#Code Block 58
df[df['Amount Funded'] == 35000 ].shape
# Out:
# (853, 25)

# %%
#Code Block 59
df[df['Amount Funded'] == 35000 ]['Amount Funded'].count()
# Out:
# 853

# %% [markdown]
# <h2 style="color:blue;">C1.S2.Py17 - Slice and Filter Data</h2>
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/frame.html and look for Indexing, iteration

# %%
#Code Block 51
df.head(2)
# Out:
#    Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 0     149512   848058       2019-08-18          19.05           7200
# 1     407046   659709       2018-05-21          10.16          16000
#
#    Total Debt  Annual Income  Revolving Accounts  Total Revolving Credit Line  \
# 0    154930.0          58000              3874.0                       4300.0
# 1     29116.0          55000              6840.0                      24800.0
#
#    Term Grade Employee Title  Length of Employment Home Ownership  \
# 0    36     D      Arkwright                   9.0           RENT
# 1    36     B         School                   4.0           RENT
#
#   Income Verification        Loan Purpose Zip Code of Residence  \
# 0     Source Verified  debt_consolidation                 028xx
# 1     Source Verified  debt_consolidation                 926xx
#
#   State of Residence  Delinquencies Past 24 Months  \
# 0                 RI                           NaN
# 1                 CA                           NaN
#
#    Credit Inquires Last 6 Months  Open Accounts TermString  Day  Month  Year
# 0                              0              6  36 months    6      8  2019
# 1                              1             12  36 months    0      5  2018

# %%
#Code Block 52
df['Member ID'].head(2)
# Out:
# 0    149512
# 1    407046
# Name: Member ID, dtype: int64

# %%
#Code Block 53
df[['Member ID']].head(2)
# Out:
#    Member ID
# 0     149512
# 1     407046

# %%
#Code Block 54
df[['Member ID', 'Loan ID','Interest Rate', 'Amount Funded']].head(2)
# Out:
#    Member ID  Loan ID  Interest Rate  Amount Funded
# 0     149512   848058          19.05           7200
# 1     407046   659709          10.16          16000

# %%
#Code Block 55
df_subset = df[['Member ID', 'Loan ID','Interest Rate', 'Amount Funded']].copy()
df_subset.head()
# Out:
#    Member ID  Loan ID  Interest Rate  Amount Funded
# 0     149512   848058          19.05           7200
# 1     407046   659709          10.16          16000
# 2     507531   601368          10.16          35000
# 3     513904   761341           6.03          21000
# 4     603349   885844          16.29          15000

# %%
#Code Block 56
df.iloc[:, [0]].head()
# Out:
#    Member ID
# 0     149512
# 1     407046
# 2     507531
# 3     513904
# 4     603349

# %%
#Code Block 57
df.iloc[:, [1, 4, 2]].head()
# Out:
#    Loan ID  Amount Funded Origination Date
# 0   848058           7200       2019-08-18
# 1   659709          16000       2018-05-21
# 2   601368          35000       2018-01-01
# 3   761341          21000       2019-01-03
# 4   885844          15000       2019-11-17

# %%
#Code Block 58
df_smallset = df.iloc[0:10, [1, 4, 2]]
df_smallset
# Out:
#    Loan ID  Amount Funded Origination Date
# 0   848058           7200       2019-08-18
# 1   659709          16000       2018-05-21
# 2   601368          35000       2018-01-01
# 3   761341          21000       2019-01-03
# 4   885844          15000       2019-11-17
# 5   613337           1500       2018-01-16
# 6   789789           7500       2019-02-17
# 7   888522          35000       2019-11-20
# 8   746115          10000       2018-12-13
# 9   812348           3600       2019-04-24

# %%
#Code Block 59
df[df['Annual Income'] > 5000000]
# Out:
#        Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# 22304    3267055   726952       2018-11-14          13.11          14825
# 29333    3979312   648723       2018-04-16          12.12          30000
#
#        Total Debt  Annual Income  Revolving Accounts  \
# 22304     69548.0        7141778             11351.0
# 29333    329254.0        6100000             15219.0
#
#        Total Revolving Credit Line  Term Grade           Employee Title  \
# 22304                      16000.0    36     B        Us postal service
# 29333                      16100.0    36     B  BOONE AND SONS JEWELERS
#
#        Length of Employment Home Ownership Income Verification  \
# 22304                  10.0       MORTGAGE     Source Verified
# 29333                  10.0       MORTGAGE            Verified
#
#              Loan Purpose Zip Code of Residence State of Residence  \
# 22304  debt_consolidation                 317xx                 GA
# 29333  debt_consolidation                 207xx                 MD
#
#        Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# 22304                           NaN                              2
# 29333                           NaN                              0
#
#        Open Accounts TermString  Day  Month  Year
# 22304             17  36 months    2     11  2018
# 29333              8  36 months    0      4  2018

# %%
#Code Block 60
df[df['Annual Income'] > 5000000].index
# Out:
# Index([22304, 29333], dtype='int64')

# %%
#Code Block 61
df.iloc[[22304, 29333], [1, 4, 2]]
# Out:
#        Loan ID  Amount Funded Origination Date
# 22304   726952          14825       2018-11-14
# 29333   648723          30000       2018-04-16

# %%
#Code Block 62
varindex = df[df['Annual Income'] > 5000000].index
df.iloc[varindex, [1, 4, 2]]
# Out:
#        Loan ID  Amount Funded Origination Date
# 22304   726952          14825       2018-11-14
# 29333   648723          30000       2018-04-16

# %%
varindex
# Out:
# Index([22304, 29333], dtype='int64')
