# %% [markdown]
# <h1 style="color:blue;">Scenario 3 - Part 1</h1>
#
# - **C1.S3.Py01 - Bar Plots using MatPlotLib and Seaborn**
# - **C1.S3.Py02 - Bar Plots with Percentages**
# - **C1.S3.Py03 - Bar Plots with Different Groupings**
# - **C1.S3.Py03b - Other Categorical Plots**
# - **C1.S3.Py04 - Pie Charts Compared to Bar Plots**
# - **C1.S3.Py05 - Histograms**
# - **C1.S3.Py06 - Describing Data**
# - **C1.S3.Py07 - Box Plots**
# - **C1.S3.Py08 - Sub Plots for Comparisons**
# - **C1.S3.Py09 - How to Transform Data**

# %%
#Code Block 1

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



#style options 

# %matplotlib inline  
#if you want graphs to automatically without plt.show

pd.set_option('display.max_columns',500) #allows for up to 500 columns to be displayed when viewing a dataframe

plt.style.use('seaborn-v0_8') #a style that can be used for plots - see style reference above

# %%
#Code Block 2
df = pd.read_csv('data/Scenario3.csv', index_col = 0, header=0) 
    #DOES NOT set the first column to the index
    # and the top row as the headers

# %%
#Code Block 3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30071 entries, 0 to 30070
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Member ID                      30071 non-null  int64
#  1   Loan ID                        30071 non-null  int64
#  2   Origination Date               30071 non-null  object
#  3   Interest Rate                  30071 non-null  float64
#  4   Amount Funded                  30071 non-null  int64
#  5   Total Debt                     30071 non-null  object
#  6   Annual Income                  30071 non-null  int64
#  7   Revolving Accounts             30071 non-null  object
#  8   Total Revolving Credit Line    30071 non-null  object
#  9   Term                           30071 non-null  int64
#  10  Grade                          30071 non-null  object
#  11  Employee Title                 28396 non-null  object
#  12  Length of Employment           28990 non-null  float64
#  13  Home Ownership                 30071 non-null  object
#  14  Income Verification            18804 non-null  object
#  15  Loan Purpose                   30071 non-null  object
#  16  Zip Code of Residence          30071 non-null  object
#  17  State of Residence             30071 non-null  object
#  18  Delinquencies Past 24 Months   4877 non-null   float64
#  19  Credit Inquires Last 6 Months  30071 non-null  int64
#  20  Open Accounts                  30071 non-null  int64
# dtypes: float64(3), int64(7), object(11)
# memory usage: 5.0+ MB

# %%
df['Home Ownership'].value_counts()
# Out:
# Home Ownership
# MORTGAGE    15484
# RENT        12212
# OWN          2303
# OTHER          37
# NONE           35
# Name: count, dtype: int64

# %% [markdown]
# ### References for visualizations using MatPlotLib or Seaborn
#
# #### Good reference for different plots
# - http://python-graph-gallery.com/
#
# #### Seaborn Reference Guide with examples
# - https://seaborn.pydata.org/
#
# #### MatplotLib Reference Guide with examples
# - https://matplotlib.org/

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py01 - Creating Bar Plots using MatPlotLib and Seaborn</h2>
#
#
# #### Reference for Bar Plots
# http://python-graph-gallery.com/barplot/

# %% [markdown]
# **Note:** MatPlotLib and Seaborn were imported in Code Block 1 as plt and sns

# %%
#Code Block 4
sns.barplot(x = "Amount Funded", data = df)
#plt.savefig('plots/barplot_h_AmountFunded.png')
# Out:
# <Axes: xlabel='Amount Funded'>

# %%
#Code Block 5
sns.barplot(y = "Amount Funded", data = df, color='green')
#plt.savefig('plots/barplot_h_AmountFunded.png')
# Out:
# <Axes: ylabel='Amount Funded'>

# %% [markdown]
# ### Adding title for the plot and x and y axis

# %%
#Code Block 6
sns.barplot(y = "Amount Funded", data = df)
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.xlabel('Amount Funded')
plt.ylabel('Dollars')
#plt.savefig('plots/barplot_h_AmountFundedWithTitle.png')
# Out:
# Text(0, 0.5, 'Dollars')

# %% [markdown]
# ### Group a barplot based on Loan Purpose

# %%
#Code Block 7
sns.set(style='white')
sns.barplot(x = "Amount Funded", y = "Loan Purpose", data = df, palette = 'deep')
#plt.savefig('plots/barplot_AmountFunded_LoanPurpose.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/347318064.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Amount Funded", y = "Loan Purpose", data = df, palette = 'deep')
# <Axes: xlabel='Amount Funded', ylabel='Loan Purpose'>

# %% [markdown]
# ### How to create a grouped barplot with MatPlotLib

# %%
#Code Block 8
result = df.groupby(["Loan Purpose"])['Amount Funded'].mean().reset_index()
result
# Out:
#           Loan Purpose  Amount Funded
# 0                  car    7687.891738
# 1          credit_card   13979.017593
# 2   debt_consolidation   15043.152252
# 3     home_improvement   13325.069444
# 4                house   15823.593750
# 5       major_purchase    8695.403226
# 6              medical    8169.087838
# 7               moving    6754.375000
# 8                other    9495.654762
# 9     renewable_energy   10249.242424
# 10      small_business   15773.726852
# 11            vacation    5922.048611
# 12             wedding   10949.259259

# %%
#Code Block 9
result = result.sort_values('Amount Funded', ascending = False)
result
# Out:
#           Loan Purpose  Amount Funded
# 4                house   15823.593750
# 10      small_business   15773.726852
# 2   debt_consolidation   15043.152252
# 1          credit_card   13979.017593
# 3     home_improvement   13325.069444
# 12             wedding   10949.259259
# 9     renewable_energy   10249.242424
# 8                other    9495.654762
# 5       major_purchase    8695.403226
# 6              medical    8169.087838
# 0                  car    7687.891738
# 7               moving    6754.375000
# 11            vacation    5922.048611

# %%
#Code Block 10
sns.set(style='white')
result.plot(kind='bar', x = "Loan Purpose", y = "Amount Funded", figsize=(20,4))
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
# Out:
# Text(0.5, 1.0, 'Average Amount Funded')

# %% [markdown]
# ### Comparable seaborn barplot

# %%
#Code Block 11
sns.set(style='dark')
plt.figure(figsize=(20,4))
sns.barplot(x = "Loan Purpose", y = "Amount Funded",  data = df, order = result['Loan Purpose'], palette = 'deep')
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
#plt.savefig('barplot_AmountFunded_LoanPurposeOrder.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/569133333.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Loan Purpose", y = "Amount Funded",  data = df, order = result['Loan Purpose'], palette = 'deep')
# Text(0.5, 1.0, 'Average Amount Funded')

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py02 - Creating Bar Plots with Percentages</h2>

# %%
#Code Block 12
df_loanpurpose = df.groupby(["Loan Purpose"])['Amount Funded'].count().reset_index()
df_loanpurpose
# Out:
#           Loan Purpose  Amount Funded
# 0                  car            351
# 1          credit_card           6764
# 2   debt_consolidation          18141
# 3     home_improvement           1440
# 4                house            160
# 5       major_purchase            620
# 6              medical            296
# 7               moving            160
# 8                other           1260
# 9     renewable_energy             33
# 10      small_business            432
# 11            vacation            144
# 12             wedding            270

# %%
#Code Block 13
df_loanpurpose.plot(kind='bar', x = "Loan Purpose", y = "Amount Funded", figsize=(20,4))
plt.title('Count Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
# Out:
# Text(0.5, 1.0, 'Count Amount Funded')

# %%
#Code Block 14
sns.set(style='whitegrid')
plt.figure(figsize=(20,4))
sns.countplot(x = "Loan Purpose",  data = df, order = result['Loan Purpose'], palette = 'deep')
plt.title('Count of Loans by Purpose', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.xlabel('Loan Purpose', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
plt.ylabel('Count', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3043954201.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Loan Purpose",  data = df, order = result['Loan Purpose'], palette = 'deep')
# Text(0, 0.5, 'Count')

# %%
#Code Block 15
df_total = df_loanpurpose['Amount Funded'].sum()
df_total
# Out:
# 30071

# %%
#Code Block 16
df_loanpurpose['Funded Percent'] = df_loanpurpose['Amount Funded'] / df_total
print(df_loanpurpose['Funded Percent'].sum())
df_loanpurpose = df_loanpurpose.sort_values('Amount Funded', ascending = False)
df_loanpurpose
# Out:
# 1.0
#           Loan Purpose  Amount Funded  Funded Percent
# 2   debt_consolidation          18141        0.603272
# 1          credit_card           6764        0.224934
# 3     home_improvement           1440        0.047887
# 8                other           1260        0.041901
# 5       major_purchase            620        0.020618
# 10      small_business            432        0.014366
# 0                  car            351        0.011672
# 6              medical            296        0.009843
# 12             wedding            270        0.008979
# 4                house            160        0.005321
# 7               moving            160        0.005321
# 11            vacation            144        0.004789
# 9     renewable_energy             33        0.001097

# %%
#Code Block 17
df_loanpurpose.plot(kind='bar', x = "Loan Purpose", y = "Funded Percent", figsize=(20,10), color = 'green')
plt.title('Percentage of Loans per Purpose', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
#plt.savefig('barplot_AmountFundedPercent_LoanPurpose.png')
# Out:
# Text(0.5, 1.0, 'Percentage of Loans per Purpose')

# %% [markdown]
# ### Embellishments of a plot
#  - palette - https://seaborn.pydata.org/tutorial/color_palettes.html
#  - order - allows bar to go from large to small or small to large
#  - title - top title for the plot, you can also change its format
#  - legend - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.legend.html

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py03 - Creating Bar Plots with Different Groupings</h2>
#
# - Look at groupings to combine categories

# %%
#Code Block 18
sns.set(style='white')
plt.figure(figsize=(20,8))
sns.countplot(x = "Loan Purpose",  data = df, palette="Paired", order = df_loanpurpose['Loan Purpose'])
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1058274776.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Loan Purpose",  data = df, palette="Paired", order = df_loanpurpose['Loan Purpose'])
# Text(0.5, 1.0, 'Average Amount Funded')

# %%
#Code Block 19
df_loanpurpose.loc[df_loanpurpose['Funded Percent'] < 0.05, 'Loan Category'] = 'Other' 
df_loanpurpose.loc[df_loanpurpose['Funded Percent'] >= 0.05, 'Loan Category'] = df_loanpurpose['Loan Purpose']

# %%
#Code Block 20
df_loanpurpose_other = df_loanpurpose.groupby(['Loan Category']).sum().reset_index()
df_loanpurpose_other
# Out:
#         Loan Category                                       Loan Purpose  \
# 0               Other  home_improvementothermajor_purchasesmall_busin...
# 1         credit_card                                        credit_card
# 2  debt_consolidation                                 debt_consolidation
#
#    Amount Funded  Funded Percent
# 0           5166        0.171793
# 1           6764        0.224934
# 2          18141        0.603272

# %%
#Code Block 21
sns.set(style='dark')
plt.figure(figsize=(20,4))
sns.barplot(x = "Loan Category", y = "Amount Funded",  data = df_loanpurpose_other, palette = 'deep')
plt.title('Count of Loans Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.xlabel('Loan Category', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
plt.ylabel('Count', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1181089760.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Loan Category", y = "Amount Funded",  data = df_loanpurpose_other, palette = 'deep')
# Text(0, 0.5, 'Count')

# %%
#Code Block 22
sns.set(style='dark')
plt.figure(figsize=(20,4))
sns.barplot(x = "Loan Category", y = "Funded Percent",  data = df_loanpurpose_other, palette = 'Purples', order = df_loanpurpose_other['Loan Category'])
plt.title('Count of Loans Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.xlabel('Loan Category', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
plt.ylabel('Percentage', fontweight='bold', color = 'green', fontsize='14', horizontalalignment='center')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/2634746589.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Loan Category", y = "Funded Percent",  data = df_loanpurpose_other, palette = 'Purples', order = df_loanpurpose_other['Loan Category'])
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py03b - Other Categorical Plots</h2>
#
# - Plotting with categorical data - https://seaborn.pydata.org/tutorial.html
#
# ### Categorical scatterplots:
#
# - :func:`stripplot` (with ``kind="strip"``; the default)
# - :func:`swarmplot` (with ``kind="swarm"``)
#
# ### Categorical distribution plots:
#
# - :func:`boxplot` (with ``kind="box"``)
# - :func:`violinplot` (with ``kind="violin"``)
# - :func:`boxenplot` (with ``kind="boxen"``)
#
# ### Categorical estimate plots:
#
# - :func:`pointplot` (with ``kind="point"``)
# - :func:`barplot` (with ``kind="bar"``)
# - :func:`countplot` (with ``kind="count"``)

# %%
#Code Block 23
sns.set(style='dark')
plt.figure(figsize=(20,4))
g = sns.catplot(y = "Loan Purpose", x = "Amount Funded", data = df, palette = 'Dark2_r')
g.fig.set_size_inches(20,5)
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/455233849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(y = "Loan Purpose", x = "Amount Funded", data = df, palette = 'Dark2_r')

# %%
#Code Block 24
sns.set(style='dark')

g = sns.catplot(y = "Loan Purpose", x = "Amount Funded", data = df, palette = 'deep', hue = "Home Ownership")
g.fig.set_size_inches(30,10)

# %%
#Code Block 25
sns.set(style='dark')
plt.figure(figsize=(20,8))
sns.stripplot(y = "Loan Purpose", x = "Amount Funded",  data = df, hue = 'Home Ownership', dodge=True, alpha=.25, zorder=1, palette="GnBu_r")
sns.pointplot(y = "Loan Purpose", x = "Amount Funded",  data = df, hue = 'Home Ownership', dodge=.532, join=False, palette="Reds",
              markers="d", scale=1, ci=None)
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1586680414.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(y = "Loan Purpose", x = "Amount Funded",  data = df, hue = 'Home Ownership', dodge=.532, join=False, palette="Reds",
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1586680414.py:5: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   sns.pointplot(y = "Loan Purpose", x = "Amount Funded",  data = df, hue = 'Home Ownership', dodge=.532, join=False, palette="Reds",
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1586680414.py:5: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.pointplot(y = "Loan Purpose", x = "Amount Funded",  data = df, hue = 'Home Ownership', dodge=.532, join=False, palette="Reds",
# <Axes: xlabel='Amount Funded', ylabel='Loan Purpose'>

# %%
#Code Block 26
sns.set(style='white')
plt.figure(figsize=(20,4))
sns.countplot(x = "Loan Purpose",  data = df, palette="Paired", order = df_loanpurpose['Loan Purpose'])
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1853729097.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Loan Purpose",  data = df, palette="Paired", order = df_loanpurpose['Loan Purpose'])
# Text(0.5, 1.0, 'Average Amount Funded')

# %%
#Code Block 27
sns.set(style='dark')
plt.figure(figsize=(20,8))
sns.countplot(x = "Loan Purpose",  data = df, order = df_loanpurpose['Loan Purpose'], palette = 'deep', hue = 'Home Ownership')
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
# Out:
# Text(0.5, 1.0, 'Average Amount Funded')

# %%
#Code Block 28
sns.set(style='dark')
plt.figure(figsize=(20,4))
sns.barplot(x = "Loan Purpose", y = "Amount Funded",  capsize=.1, data = df, order = result['Loan Purpose'], palette = 'deep', hue = 'Home Ownership')
plt.title('Average Amount Funded', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.legend(loc='upper right')

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py04 - Creating Pie Charts Compared to Bar Plots</h2>
#
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html?highlight=pie#matplotlib.pyplot.pie

# %%
#Code Block 29
df_homeownership = df.groupby('Home Ownership')['Amount Funded'].count().reset_index()
df_homeownership = df_homeownership.sort_values('Amount Funded', ascending = False)
df_homeownership
# Out:
#   Home Ownership  Amount Funded
# 0       MORTGAGE          15484
# 4           RENT          12212
# 3            OWN           2303
# 2          OTHER             37
# 1           NONE             35

# %%
#Code Block 30
plt.pie(df_homeownership['Amount Funded'], labels=df_homeownership['Home Ownership'], shadow=True, startangle=200)
plt.savefig('plots/piechart_HomeOwnership.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[103], line 3
#       1 #Code Block 30
#       2 plt.pie(df_homeownership['Amount Funded'], labels=df_homeownership['Home Ownership'], shadow=True, startangle=200)
# ----> 3 plt.savefig('plots/piechart_HomeOwnership.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/piechart_HomeOwnership.png'

# %%
#Code Block 31
plt.figure(figsize=(20,20))
plt.pie(df_homeownership['Amount Funded'], labels=df_homeownership['Home Ownership'], shadow=False, startangle=200)
# Out:
# ([<matplotlib.patches.Wedge at 0x31dfb1220>,
#   <matplotlib.patches.Wedge at 0x31d87ca70>,
#   <matplotlib.patches.Wedge at 0x31dfb3b30>,
#   <matplotlib.patches.Wedge at 0x31dfb3e90>,
#   <matplotlib.patches.Wedge at 0x31dff0260>],
#  [Text(0.4242246622967759, -1.014905629060745, 'MORTGAGE'),
#   Text(-0.16198818027197284, 1.0880072745400993, 'RENT'),
#   Text(-1.09520331804421, -0.10261428821052672, 'OWN'),
#   Text(-1.0378028681132785, -0.36464394542601847, 'OTHER'),
#   Text(-1.0350306750388538, -0.3724399303627564, 'NONE')])

# %%
#Code Block 32
plt.figure(figsize=(10,10))
plt.pie(df_homeownership['Amount Funded'], explode = (0, 0, .2, 0, 0), wedgeprops = {'linewidth': 3}, labels=df_homeownership['Home Ownership'], startangle=140, autopct='%1.1f%%')
plt.savefig('plots/piechart_HomeOwnership_Explode.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[120], line 4
#       2 plt.figure(figsize=(10,10))
#       3 plt.pie(df_homeownership['Amount Funded'], explode = (0, 0, .2, 0, 0), wedgeprops = {'linewidth': 3}, labels=df_homeownership['Home Ownership'], startangle=140, autopct='%1.1f%%')
# ----> 4 plt.savefig('plots/piechart_HomeOwnership_Explode.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/piechart_HomeOwnership_Explode.png'

# %% [markdown]
# ### Creating subplots to compare pie charts and bar plots
#
# - Link to show how to create subplots - https://python-graph-gallery.com/194-split-the-graphic-window-with-subplot/

# %%
#Code Block 33
plt.style.use('ggplot')
plt.figure(figsize=(20,8))
plt.subplot(121)
plt.pie(df_homeownership['Amount Funded'], wedgeprops = {'linewidth': 3}, labels=df_homeownership['Home Ownership'], startangle=140, autopct='%1.1f%%')
plt.subplot(122)
sns.barplot(y = "Home Ownership", x = "Amount Funded",  data = df_homeownership)
plt.savefig('plots/piechart_barplot_HomeOwnership.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[123], line 8
#       6 plt.subplot(122)
#       7 sns.barplot(y = "Home Ownership", x = "Amount Funded",  data = df_homeownership)
# ----> 8 plt.savefig('plots/piechart_barplot_HomeOwnership.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/piechart_barplot_HomeOwnership.png'

# %%
#Code Block 34
sns.set(style='dark')
plt.figure(figsize=(20,16))
plt.subplot(121)
plt.pie(df_loanpurpose['Funded Percent'], labels=df_loanpurpose['Loan Purpose'], startangle=180, autopct='%1.1f%%')
plt.subplot(122)
sns.barplot(y = "Loan Purpose", x = "Amount Funded",  data = df_loanpurpose, palette = 'deep')
plt.savefig('plots/piechart_barplot_LoanPurpose.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/953617599.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = "Loan Purpose", x = "Amount Funded",  data = df_loanpurpose, palette = 'deep')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[125], line 8
#       6 plt.subplot(122)
#       7 sns.barplot(y = "Loan Purpose", x = "Amount Funded",  data = df_loanpurpose, palette = 'deep')
# ----> 8 plt.savefig('plots/piechart_barplot_LoanPurpose.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/piechart_barplot_LoanPurpose.png'

# %%
#Code Block 35
sns.set(style='dark')
plt.figure(figsize=(20,8))
plt.subplot(121)
plt.pie(df_loanpurpose_other['Funded Percent'], explode = (0.2, 0, 0), wedgeprops = {'linewidth': 3}, labels=df_loanpurpose_other['Loan Category'], startangle=140, autopct='%1.1f%%')
plt.subplot(122)
sns.barplot(x = "Loan Category", y = "Amount Funded",  data = df_loanpurpose_other, palette = 'deep')
plt.savefig('plots/piechart_barplot_LoanCategory.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3600448278.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Loan Category", y = "Amount Funded",  data = df_loanpurpose_other, palette = 'deep')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[127], line 8
#       6 plt.subplot(122)
#       7 sns.barplot(x = "Loan Category", y = "Amount Funded",  data = df_loanpurpose_other, palette = 'deep')
# ----> 8 plt.savefig('plots/piechart_barplot_LoanCategory.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/piechart_barplot_LoanCategory.png'

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py05 - Creating a Histogram</h2>

# %%
#Code Block 36
# Plot a simple histogram with binsize determined automatically
sns.distplot(df['Interest Rate'], kde=False, color="b")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/2328028195.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Interest Rate'], kde=False, color="b")
# <Axes: xlabel='Interest Rate'>

# %%
#Code Block 37
# Plot a kernel density estimate and rug plot
sns.distplot(df['Interest Rate'], hist=False, rug=True, color="r")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1815327474.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Interest Rate'], hist=False, rug=True, color="r")
# <Axes: xlabel='Interest Rate', ylabel='Density'>

# %%
#Code Block 38
sns.distplot(df['Interest Rate'], hist=False, color="g", kde_kws={"shade": True})
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1737535584.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Interest Rate'], hist=False, color="g", kde_kws={"shade": True})
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: xlabel='Interest Rate', ylabel='Density'>

# %%
#Code Block 39
# Plot a histogram and kernel density estimate and color magenta
sns.distplot(df['Interest Rate'], color="m", bins=10)
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3721820238.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Interest Rate'], color="m", bins=10)
# <Axes: xlabel='Interest Rate', ylabel='Density'>

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py06 - Describing Data</h2>

# %%
#Code Block 40
df.head()
# Out:
#     Member ID  Loan ID Origination Date  Interest Rate  Amount Funded  \
# No
# 0     1682817   600960           1/1/18           6.03          10800
# 1     1729549   600988           1/1/18          11.14          12575
# 2     1735588   601001           1/1/18           7.90          27575
# 3     1738054   601008           1/1/18          13.11           1600
# 4     1763680   601075           1/1/18           8.90           5000
#
#    Total Debt  Annual Income Revolving Accounts Total Revolving Credit Line  \
# No
# 0       15175          86000               8030                       22400
# 1      458929          80000              12465                       13500
# 2       30452          70000              30452                       63700
# 3        5453          25000               5453                        6900
# 4      310278         105000              23423                       42900
#
#     Term Grade             Employee Title  Length of Employment  \
# No
# 0     36     A             SmartPros Ltd.                   3.0
# 1     36     B      Saddleback Valley USD                  10.0
# 2     36     A                  Geo Group                  10.0
# 3     36     B  Swedish Covenant Hospital                  10.0
# 4     36     A   Williams Baptist College                  10.0
#
#    Home Ownership Income Verification        Loan Purpose  \
# No
# 0            RENT                 NaN  debt_consolidation
# 1        MORTGAGE                 NaN  debt_consolidation
# 2             OWN                 NaN  debt_consolidation
# 3            RENT                 NaN      major_purchase
# 4        MORTGAGE                 NaN  debt_consolidation
#
#    Zip Code of Residence State of Residence  Delinquencies Past 24 Months  \
# No
# 0                  088xx                 NJ                           NaN
# 1                  926xx                 CA                           NaN
# 2                  797xx                 TX                           NaN
# 3                  606xx                 IL                           NaN
# 4                  724xx                 AR                           NaN
#
#     Credit Inquires Last 6 Months  Open Accounts
# No
# 0                               0             11
# 1                               0              7
# 2                               0              5
# 3                               0              8
# 4                               0             16

# %%
#Code Block 41
df.describe()
# Out:
#           Member ID        Loan ID  Interest Rate  Amount Funded  \
# count  3.007100e+04   30071.000000   30071.000000   30071.000000
# mean   2.558148e+06  758572.627814      13.761040   14089.528117
# std    8.106320e+05   91431.818948       4.179612    8045.157332
# min    1.495120e+05  600947.000000       6.000000    1000.000000
# 25%    1.837828e+06  679267.000000      11.140000    8000.000000
# 50%    2.287587e+06  758139.000000      14.090000   12000.000000
# 75%    3.408782e+06  838127.000000      16.290000   19750.000000
# max    4.076727e+06  917123.000000      24.890000   35000.000000
#
#        Annual Income          Term  Length of Employment  \
# count   3.007100e+04  30071.000000          28990.000000
# mean    7.378315e+04     40.098301              6.073577
# std     8.012846e+04      9.031382              3.438755
# min     7.200000e+03     36.000000              1.000000
# 25%     4.500000e+04     36.000000              3.000000
# 50%     6.300000e+04     36.000000              6.000000
# 75%     8.800000e+04     36.000000             10.000000
# max     7.141778e+06     60.000000             10.000000
#
#        Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# count                   4877.000000                   30071.000000
# mean                       1.476727                       0.820525
# std                        1.027374                       1.019112
# min                        1.000000                       0.000000
# 25%                        1.000000                       0.000000
# 50%                        1.000000                       1.000000
# 75%                        2.000000                       1.000000
# max                       18.000000                       8.000000
#
#        Open Accounts
# count   30071.000000
# mean       10.982907
# std         4.523027
# min         0.000000
# 25%         8.000000
# 50%        10.000000
# 75%        14.000000
# max        53.000000

# %%
#Code Block 42
df.describe(include='all')
# Out:
#            Member ID        Loan ID Origination Date  Interest Rate  \
# count   3.007100e+04   30071.000000            30071   30071.000000
# unique           NaN            NaN              515            NaN
# top              NaN            NaN           1/7/18            NaN
# freq             NaN            NaN              172            NaN
# mean    2.558148e+06  758572.627814              NaN      13.761040
# std     8.106320e+05   91431.818948              NaN       4.179612
# min     1.495120e+05  600947.000000              NaN       6.000000
# 25%     1.837828e+06  679267.000000              NaN      11.140000
# 50%     2.287587e+06  758139.000000              NaN      14.090000
# 75%     3.408782e+06  838127.000000              NaN      16.290000
# max     4.076727e+06  917123.000000              NaN      24.890000
#
#         Amount Funded Total Debt  Annual Income Revolving Accounts  \
# count    30071.000000      30071   3.007100e+04              30071
# unique            NaN      28081            NaN              19900
# top               NaN       -               NaN               -
# freq              NaN          8            NaN                 88
# mean     14089.528117        NaN   7.378315e+04                NaN
# std       8045.157332        NaN   8.012846e+04                NaN
# min       1000.000000        NaN   7.200000e+03                NaN
# 25%       8000.000000        NaN   4.500000e+04                NaN
# 50%      12000.000000        NaN   6.300000e+04                NaN
# 75%      19750.000000        NaN   8.800000e+04                NaN
# max      35000.000000        NaN   7.141778e+06                NaN
#
#        Total Revolving Credit Line          Term  Grade Employee Title  \
# count                        30071  30071.000000  30071          28396
# unique                        3529           NaN      7          23366
# top                           9000           NaN      B        US Army
# freq                           111           NaN  11370            107
# mean                           NaN     40.098301    NaN            NaN
# std                            NaN      9.031382    NaN            NaN
# min                            NaN     36.000000    NaN            NaN
# 25%                            NaN     36.000000    NaN            NaN
# 50%                            NaN     36.000000    NaN            NaN
# 75%                            NaN     36.000000    NaN            NaN
# max                            NaN     60.000000    NaN            NaN
#
#         Length of Employment Home Ownership Income Verification  \
# count           28990.000000          30071               18804
# unique                   NaN              5                   2
# top                      NaN       MORTGAGE            Verified
# freq                     NaN          15484               13599
# mean                6.073577            NaN                 NaN
# std                 3.438755            NaN                 NaN
# min                 1.000000            NaN                 NaN
# 25%                 3.000000            NaN                 NaN
# 50%                 6.000000            NaN                 NaN
# 75%                10.000000            NaN                 NaN
# max                10.000000            NaN                 NaN
#
#               Loan Purpose Zip Code of Residence State of Residence  \
# count                30071                 30071              30071
# unique                  13                   790                 45
# top     debt_consolidation                 945xx                 CA
# freq                 18141                   403               5186
# mean                   NaN                   NaN                NaN
# std                    NaN                   NaN                NaN
# min                    NaN                   NaN                NaN
# 25%                    NaN                   NaN                NaN
# 50%                    NaN                   NaN                NaN
# 75%                    NaN                   NaN                NaN
# max                    NaN                   NaN                NaN
#
#         Delinquencies Past 24 Months  Credit Inquires Last 6 Months  \
# count                    4877.000000                   30071.000000
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                        1.476727                       0.820525
# std                         1.027374                       1.019112
# min                         1.000000                       0.000000
# 25%                         1.000000                       0.000000
# 50%                         1.000000                       1.000000
# 75%                         2.000000                       1.000000
# max                        18.000000                       8.000000
#
#         Open Accounts
# count    30071.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        10.982907
# std          4.523027
# min          0.000000
# 25%          8.000000
# 50%         10.000000
# 75%         14.000000
# max         53.000000

# %%
#Code Block 43
df[['Interest Rate', 'Annual Income', 'Amount Funded']].describe()
# Out:
#        Interest Rate  Annual Income  Amount Funded
# count   30071.000000   3.007100e+04   30071.000000
# mean       13.761040   7.378315e+04   14089.528117
# std         4.179612   8.012846e+04    8045.157332
# min         6.000000   7.200000e+03    1000.000000
# 25%        11.140000   4.500000e+04    8000.000000
# 50%        14.090000   6.300000e+04   12000.000000
# 75%        16.290000   8.800000e+04   19750.000000
# max        24.890000   7.141778e+06   35000.000000

# %%
#Code Block 44
df['Interest Rate'].describe()
# Out:
# count    30071.000000
# mean        13.761040
# std          4.179612
# min          6.000000
# 25%         11.140000
# 50%         14.090000
# 75%         16.290000
# max         24.890000
# Name: Interest Rate, dtype: float64

# %%
#Code Block 45
df_int_rate = df['Interest Rate'].describe().reset_index()
df_int_rate
# Out:
#    index  Interest Rate
# 0  count   30071.000000
# 1   mean      13.761040
# 2    std       4.179612
# 3    min       6.000000
# 4    25%      11.140000
# 5    50%      14.090000
# 6    75%      16.290000
# 7    max      24.890000

# %%
#Code Block 46
int_skew = df['Interest Rate'].skew()
int_skew
# Out:
# 0.19695216788797454

# %%
#Code Block 47
new_row = {'index':'skew', 'Interest Rate': int_skew}
#append row to the dataframe
df_int_rate = df_int_rate.append(new_row, ignore_index=True)
df_int_rate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/2851904624.py in ?()
#       1 #Code Block 47
#       2 new_row = {'index':'skew', 'Interest Rate': int_skew}
#       3 #append row to the dataframe
# ----> 4 df_int_rate = df_int_rate.append(new_row, ignore_index=True)
#       5 df_int_rate
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#Code Block 48
int_median = df['Interest Rate'].median()
new_row = {'index':'median', 'Interest Rate': int_median}
#append row to the dataframe
df_int_rate = df_int_rate.append(new_row, ignore_index=True)

int_var = df['Interest Rate'].var()
new_row = {'index':'var', 'Interest Rate': int_var}
#append row to the dataframe
df_int_rate = df_int_rate.append(new_row, ignore_index=True)

df_int_rate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3665609755.py in ?()
#       1 #Code Block 48
#       2 int_median = df['Interest Rate'].median()
#       3 new_row = {'index':'median', 'Interest Rate': int_median}
#       4 #append row to the dataframe
# ----> 5 df_int_rate = df_int_rate.append(new_row, ignore_index=True)
#       6
#       7 int_var = df['Interest Rate'].var()
#       8 new_row = {'index':'var', 'Interest Rate': int_var}
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py07 - Creating Box Plots</h2>

# %%
#Code Block 49
df['Amount Funded'].plot(kind= 'box')
# Out:
# <Axes: >

# %%
#Code Block 51
sns.boxplot(y = "Amount Funded",  data = df)
# Out:
# <Axes: ylabel='Amount Funded'>

# %%
#Code Block 52
plt.figure(figsize=(20,8))
sns.boxplot(y = "Amount Funded", x = "Home Ownership", data = df)
plt.savefig('plots/Boxplot_Homeownership.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[166], line 4
#       2 plt.figure(figsize=(20,8))
#       3 sns.boxplot(y = "Amount Funded", x = "Home Ownership", data = df)
# ----> 4 plt.savefig('plots/Boxplot_Homeownership.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/Boxplot_Homeownership.png'

# %%
#Code Block 53
plt.figure(figsize=(20,8))
sns.boxplot(x = "Amount Funded", y = "Home Ownership", data = df)
# Out:
# <Axes: xlabel='Amount Funded', ylabel='Home Ownership'>

# %%
#Code Block 54
plt.figure(figsize=(20,8))
sns.boxplot(y = "Amount Funded", x = "Loan Purpose", data = df)
plt.savefig('plots/Boxplot_LoanPurpose.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[172], line 4
#       2 plt.figure(figsize=(20,8))
#       3 sns.boxplot(y = "Amount Funded", x = "Loan Purpose", data = df)
# ----> 4 plt.savefig('plots/Boxplot_LoanPurpose.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/Boxplot_LoanPurpose.png'

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py08 - How to Create Sub Plots for Comparisons     </h2>

# %%
##### Code Block 55
plt.figure(figsize=(16,8))
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/902663611.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# <Axes: title={'center': 'Boxplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 56
plt.figure(figsize=(20,8))
plt.title('Violinplot', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/813751259.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
# <Axes: title={'center': 'Violinplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 57
plt.figure(figsize=(20,8))
plt.title('Boxenplot', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1472717044.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# <Axes: title={'center': 'Boxenplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 58
plt.figure(figsize=(20,4))
plt.subplot(131)
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
plt.subplot(132)
plt.title('Violinplot', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
plt.subplot(133)
plt.title('Boxenplot', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1282154089.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1282154089.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1282154089.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# <Axes: title={'center': 'Boxenplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 59
df_income_onemil = df[df['Annual Income'] < 1000000]

# %%
#Code Block 60
plt.figure(figsize=(16,8))
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df_income_onemil, palette = "Greens")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/2017475124.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df_income_onemil, palette = "Greens")
# <Axes: title={'center': 'Boxplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 61
plt.figure(figsize=(16,8))
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
plt.ylim((0,1000000))
sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3340977738.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# <Axes: title={'center': 'Boxplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 62
plt.figure(figsize=(16,8))
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
plt.ylim((0,400000))
sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1016777398.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# <Axes: title={'center': 'Boxplot'}, xlabel='Home Ownership', ylabel='Annual Income'>

# %%
#Code Block 63
plt.figure(figsize=(20,12))
ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
plt.title('Boxplot', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
plt.ylim((0,400000))
ax1 = sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
ax2 = plt.subplot2grid((2, 2), (1, 0), colspan=1)
plt.title('Violinplot', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
ax2 = sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
ax3 = plt.subplot2grid((2, 2), (1, 1), colspan=1)
plt.ylim((0,1000000))
plt.title('Boxenplot', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
ax3 = sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
plt.savefig('plots/Box_Violin_BoxenPlots_Homeownership.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1315397088.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.boxplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Greens")
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1315397088.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.violinplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Blues")
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/1315397088.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax3 = sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[216], line 14
#      12 plt.title('Boxenplot', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
#      13 ax3 = sns.boxenplot(y = "Annual Income", x = "Home Ownership", data = df, palette = "Reds")
# ---> 14 plt.savefig('plots/Box_Violin_BoxenPlots_Homeownership.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/Box_Violin_BoxenPlots_Homeownership.png'

# %% [markdown]
# <h2 style="color:blue;">C1.S3.Py09 How to Transform Data</h2>

# %%
#Code Block 64
df_income = df['Annual Income']
df_income = pd.DataFrame(df_income).reset_index()
df_income
# Out:
#           No  Annual Income
# 0          0          86000
# 1          1          80000
# 2          2          70000
# 3          3          25000
# 4          4         105000
# ...      ...            ...
# 30066  30066         115000
# 30067  30067          44000
# 30068  30068          78000
# 30069  30069         240000
# 30070  30070          38000
#
# [30071 rows x 2 columns]

# %% [markdown]
# ### Z-Score Explained
# - https://www.statisticshowto.com/probability-and-statistics/z-score/
#
# #### Example of a z-score
# - mean = 10
# - standard deviation = 5
# - X = 17.5
# - Z-score = (17.5 - 10) / 5 = 1.5

# %%
#Code Block 65
mean_income = df_income['Annual Income'].mean()
stdev_income = df_income['Annual Income'].std()
df_income['z_score'] = ((df_income['Annual Income']-mean_income)/stdev_income)
df_income
# Out:
#           No  Annual Income   z_score
# 0          0          86000  0.152466
# 1          1          80000  0.077586
# 2          2          70000 -0.047214
# 3          3          25000 -0.608812
# 4          4         105000  0.389585
# ...      ...            ...       ...
# 30066  30066         115000  0.514385
# 30067  30067          44000 -0.371693
# 30068  30068          78000  0.052626
# 30069  30069         240000  2.074380
# 30070  30070          38000 -0.446572
#
# [30071 rows x 3 columns]

# %% [markdown]
# ### What is a log?
# - How many of one number do we multiply to get another number?
#
# #### log(e)
# - Also known as the natural log used Euler's Number which is approximately 2.718
# - Example: loge(7.389) ≈ 2 - because 2.71828^2 ≈ 7.389
#
# #### log2
# - What is log2(64)?
# - We are asking "how many 2s need to be multiplied together to get 64?"
# - 2 × 2 × 2 × 2 × 2 × 2 = 64, so we need 6 of the 2s
# - Answer: log2(64) = 6
#
# #### log10
# - What is log10(1000)?
# - We are asking "how many 10s need to be multiplied together to get 1000?"
# - 10 × 10 × 10 = 1000, so we need 3 of the 10s
# - Answer: log100(1000) = 3

# %%
#Code Block 66
df_income['loge'] = np.log(df_income['Annual Income'])
df_income['log2'] = np.log2(df_income['Annual Income'])
df_income['log10'] = np.log10(df_income['Annual Income'])
df_income.head(15)
# Out:
#     No  Annual Income   z_score       loge       log2     log10
# 0    0          86000  0.152466  11.362103  16.392049  4.934498
# 1    1          80000  0.077586  11.289782  16.287712  4.903090
# 2    2          70000 -0.047214  11.156251  16.095067  4.845098
# 3    3          25000 -0.608812  10.126631  14.609640  4.397940
# 4    4         105000  0.389585  11.561716  16.680030  5.021189
# 5    5          80000  0.077586  11.289782  16.287712  4.903090
# 6    6          50000 -0.296813  10.819778  15.609640  4.698970
# 7    7          55000 -0.234413  10.915088  15.747144  4.740363
# 8    8          65000 -0.109613  11.082143  15.988152  4.812913
# 9    9          87000  0.164946  11.373663  16.408728  4.939519
# 10  10          60000 -0.172013  11.002100  15.872675  4.778151
# 11  11          90000  0.202386  11.407565  16.457637  4.954243
# 12  12          43000 -0.384172  10.668955  15.392049  4.633468
# 13  13          65000 -0.109613  11.082143  15.988152  4.812913
# 14  14         148500  0.932463  11.908340  17.180103  5.171726

# %%
#Code Block 67
plt.figure(figsize=(20,16))
plt.subplot(231)
plt.title('Raw Data', fontweight='bold', color = 'green', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['Annual Income'], color="g", bins = 20)
plt.subplot(232)
plt.title('Z Score', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['z_score'], color="b", bins = 20)
plt.subplot(233)
plt.title('Natural log', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['loge'], color="r", bins = 20)
plt.subplot(234)
plt.title('Log2', fontweight='bold', color = 'black', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['log2'], color="y", bins = 20)
plt.subplot(235)
plt.title('Log10', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['log10'], color="m", bins = 20)
plt.subplot(236)
plt.title('Log10', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
sns.distplot(df_income['log10'], color="m", bins = 50)
plt.savefig('plots/Transform_Histogram_AnnualIncome.png')
# Out:
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['Annual Income'], color="g", bins = 20)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['z_score'], color="b", bins = 20)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['loge'], color="r", bins = 20)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['log2'], color="y", bins = 20)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['log10'], color="m", bins = 20)
# /var/folders/ww/gvxz55x16sj2qt6_7hv99n0w0000gn/T/ipykernel_72134/3099395568.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['log10'], color="m", bins = 50)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[241], line 21
#      19 plt.title('Log10', fontweight='bold', color = 'red', fontsize='17', horizontalalignment='center')
#      20 sns.distplot(df_income['log10'], color="m", bins = 50)
# ---> 21 plt.savefig('plots/Transform_Histogram_AnnualIncome.png')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/donovanmanogue/Documents/Data 6300/Scenario03/plots/Transform_Histogram_AnnualIncome.png'
